# %% [markdown]
# # Motivation
#
# The logo idea is inspired from [sequence logos](https://en.wikipedia.org/wiki/Sequence_logo) which find ubiqutious use across different research areas in Biology.
# I use our package [pyseqlogo](http://github.com/saketkc/pyseqlogo) for drawing. Some designs might require editing later to get rid of overlapping curves, but everything otherwise
# is generated through code. The underlying idea for all logos remain the same, I just fiddle around with fonts. A list of all other (cool) fonts is [here](PrintAllFonts.html) (WARNING: might be slow to load)

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from __future__ import division
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
from Bio import SeqIO
from pyseqlogo.pyseqlogo import draw_logo
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
alphabets = set(['R', 'E', 'T', 'R', 'E', 'A', 'T', 'M', 'C', 'B'])
alphabets
# Out:
# {'A', 'B', 'C', 'E', 'M', 'R', 'T'}

# %%
colors = {'A': '#E60A0A', 
          'B': '#145AFF',
          'C': '#145AFF',
          'E': '#E60A0A',
          'M': '#145AFF',
          'R': '#E60A0A',
          'T': '#E60A0A'
         }

# %%
counts_mcb = {'A': [0,0,0,0,0,200,0],
              'B': [0,0,0,0,0,100,0],
              'C': [0,0,0,300,0,0,0],
              'E': [0,210,0,0,100,0,0],
              'M': [0,200,0,0,0,0,0],
              'R': [200,0,0,200,0,0,0],
              'T': [0,0,10,0,0,0,10]
             }

# %% [markdown]
# # D1

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Betsy Flanagan',
                       colorscheme=colors)

# %% [markdown]
# # D1 Stranded

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Betsy Flanagan',
                       colorscheme=colors)


theta_max = 2.2*np.pi
n = 1000
theta = np.linspace(0, theta_max, n)
x = theta + 0.4
z =  -0.1*np.sin(theta*1.25)+0.05
z1 =  -0.1*np.sin(theta*1.25 + np.pi)+0.05
axarr[0][0].plot(x, z, color='#145AFF')
axarr[0][0].plot(x, z1, color='#E60A0A')

# %% [markdown]
# # D2

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Binary CHR BRK',
                       colorscheme=colors)

# %% [markdown]
# # D3

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='CrackMan',
                       colorscheme=colors)

# %% [markdown]
# # D4

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Dash Dot BRK',
                       colorscheme=colors)

# %% [markdown]
# # D5

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Corpulent Caps Shadow BRK',
                       colorscheme=colors)

# %% [markdown]
# # D4 stranded

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Corpulent Caps Shadow BRK',
                       colorscheme=colors)

theta_max = 2.2*np.pi
n = 1000
theta = np.linspace(0, theta_max, n)
x = theta + 0.4
z =  -0.1*np.sin(theta*1.25)+0.05
z1 =  -0.1*np.sin(theta*1.25 + np.pi)+0.05
axarr[0][0].plot(x, z, color='#145AFF')
axarr[0][0].plot(x, z1, color='#E60A0A')

# %% [markdown]
# # D5

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Earwig Factory',
                       colorscheme=colors)

# %%
fig, axarr = draw_logo(counts_mcb, 
                       data_type='counts', 
                       yaxis='probability', 
                       fontfamily='Earwig Factory',
                       colorscheme=colors)




theta_max = 2.2*np.pi
n = 1000
theta = np.linspace(0, theta_max, n)
x = theta + 0.4
z =  -0.1*np.sin(theta*1.25)+0.02
z1 =  -0.1*np.sin(theta*1.25 + np.pi)+0.02
axarr[0][0].plot(x, z, color='#145AFF')
axarr[0][0].plot(x, z1, color='#E60A0A')
